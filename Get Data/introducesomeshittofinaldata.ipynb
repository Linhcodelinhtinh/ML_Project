# %%
import pandas as pd
import re
import pickle
import random

# %%
data = pd.read_csv('final_data.csv', index_col=0)
data

# %%
data.loc[0, 'SCOREMARGIN'] = 0
for i in range(1, 124992):
    if pd.isna(data.loc[i, 'SCOREMARGIN']) or data.loc[i, 'SCOREMARGIN'] == 0:
        data.loc[i, 'SCOREMARGIN'] = data.loc[i - 1, 'SCOREMARGIN']
    if data.loc[i, 'PERIOD'] == 1 and data.loc[i-1, 'PERIOD'] == 4:
        data.loc[i, 'SCOREMARGIN'] = 0
data.loc[data['SCOREMARGIN'] == "TIE", 'SCOREMARGIN'] = 0
data

# %%
data.loc[0, 'SCORE'] = "0 - 0"
for i in range(1, 124992):
    if pd.isna(data.loc[i, 'SCORE']) or data.loc[i, 'SCORE'] == "0 - 0":
        data.loc[i, 'SCORE'] = data.loc[i - 1, 'SCORE']
    if data.loc[i, 'PERIOD'] == 1 and data.loc[i-1, 'PERIOD'] == 4:
        data.loc[i, 'SCORE'] = "0 - 0"
        
data

# %%
SCORE_1 = []
SCORE_2 = []
for i in range(124992):
    match = re.match(r"(\d+)\s*-\s*(\d+)", data.loc[i, 'SCORE'])
    if match:
        SCORE_1.append(int(match.group(1)))
        SCORE_2.append(int(match.group(2)))
data['SCORE_1'] = SCORE_1
data['SCORE_2'] = SCORE_2

# %%
data.drop(columns=['SCORE'], inplace=True)

# %%
result = []
for i in range(124991):
    if data.loc[i, 'PERIOD'] == 4 and (data.loc[i+1, 'PERIOD'] == 1):
        if data.loc[i, 'SCORE_1'] > data.loc[i, 'SCORE_2']:
            result.append(data.loc[i, 'TEAM_1'])
        else:
            result.append(data.loc[i, 'TEAM_2'])
if data.loc[124991, 'SCORE_1'] > data.loc[124991, 'SCORE_2']:
    result.append(data.loc[124991, 'TEAM_1'])
else:
    result.append(data.loc[124991, 'TEAM_2'])
result

# %%
j = 0
data['WINNER'] = pd.Series()
for i in range(124991):
    data.loc[i, 'WINNER'] = result[j]
    if data.loc[i, 'PERIOD'] == 4 and (data.loc[i+1, 'PERIOD'] == 1):
        j+=1
data.loc[124991, "WINNER"] = result[j]
data

# %%
data.loc[data['PERIOD'] > 1,'TIME_REMAINING'] += 720*(data['PERIOD']-1)
data

# %%
# data.to_csv('final_data.csv')

# %%
data = pd.read_csv('final_data.csv', index_col=0)
data

# %%
data.SCOREMARGIN = -1*data.SCOREMARGIN

# %%
grouped = data.groupby(['GAME_ID'])
grouped_dataframes = [group for _, group in grouped]
random.shuffle(grouped_dataframes)
grouped_dataframes[263]

# %%
with open('train_set.pkl', 'wb') as file:
    pickle.dump(grouped_dataframes[:184], file)
with open('test_set.pkl', 'wb') as file:
    pickle.dump(grouped_dataframes[184:], file)

# %%
with open('Data/train_set.pkl', 'rb') as file:
    train_set = pickle.load(file)
with open('Data/test_set.pkl', 'rb') as file:
    test_set = pickle.load(file)

# Access the DataFrames
train_set[0]
# Out:
#          GAME_ID  SCOREMARGIN  TIME_REMAINING  PERIOD TEAM_1 TEAM_2  \
# 101817  22400025            0               0       1    OKC    SAS
# 101818  22400025            0               0       1    OKC    SAS
# 101819  22400025           -2              25       1    OKC    SAS
# 101820  22400025            1              35       1    OKC    SAS
# 101821  22400025           -2              48       1    OKC    SAS
# ...          ...          ...             ...     ...    ...    ...
# 102272  22400025           -6            2871       4    OKC    SAS
# 102273  22400025           -6            2873       4    OKC    SAS
# 102274  22400025           -6            2875       4    OKC    SAS
# 102275  22400025           -6            2875       4    OKC    SAS
# 102276  22400025           -6            2880       4    OKC    SAS
#
#            PLAYER_1.1     PLAYER_1.2      PLAYER_1.3     PLAYER_1.4  \
# 101817  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 101818  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 101819  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 101820  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 101821  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# ...               ...            ...             ...            ...
# 102272  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 102273  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 102274  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 102275  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 102276  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
#
#                      PLAYER_1.5         PLAYER_2.1       PLAYER_2.2  \
# 101817  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 101818  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 101819  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 101820  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 101821  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# ...                         ...                ...              ...
# 102272  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 102273  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 102274  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 102275  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 102276  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
#
#           PLAYER_2.3      PLAYER_2.4  PLAYER_2.5  SCORE_1  SCORE_2 WINNER
# 101817  Zach Collins  Stephon Castle  Chris Paul        0        0    SAS
# 101818  Zach Collins  Stephon Castle  Chris Paul        0        0    SAS
# 101819  Zach Collins  Stephon Castle  Chris Paul        0        2    SAS
# 101820  Zach Collins  Stephon Castle  Chris Paul        3        2    SAS
# 101821  Zach Collins  Stephon Castle  Chris Paul        3        5    SAS
# ...              ...             ...         ...      ...      ...    ...
# 102272  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
# 102273  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
# 102274  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
# 102275  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
# 102276  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
#
# [460 rows x 19 columns]

# %%
train_set[0] = train_set[0].reset_index(drop=True)

# %%
for j in range(len(train_set)):
    temp = train_set[j].copy()
    for i in train_set[j].index:
        if i>0:
            if train_set[j][i - 1]['SCOREMARGIN'] == train_set[j][i]['SCOREMARGIN']:
                if random.random() < 0.8:
                    temp = temp.drop(index=i)
    train_set[j] = temp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       3 for i in train_set[j].index:
#       4     if i>0:
# ----> 5         if train_set[j][i - 1]['SCOREMARGIN'] == train_set[j][i]['SCOREMARGIN']:
#       6             if random.random() < 0.8:
#       7                 temp = temp.drop(index=i)
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 1

# %%
for j in range(len(train_set)):
    print(train_set[j])
# Out:
#       GAME_ID  SCOREMARGIN  TIME_REMAINING  PERIOD TEAM_1 TEAM_2  \
# 0    22400025            0               0       1    OKC    SAS
# 2    22400025           -2              25       1    OKC    SAS
# 3    22400025            1              35       1    OKC    SAS
# 4    22400025           -2              48       1    OKC    SAS
# 5    22400025           -2              65       1    OKC    SAS
# ..        ...          ...             ...     ...    ...    ...
# 455  22400025           -6            2871       4    OKC    SAS
# 456  22400025           -6            2873       4    OKC    SAS
# 457  22400025           -6            2875       4    OKC    SAS
# 458  22400025           -6            2875       4    OKC    SAS
# 459  22400025           -6            2880       4    OKC    SAS
#
#         PLAYER_1.1     PLAYER_1.2      PLAYER_1.3     PLAYER_1.4  \
# 0    Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 2    Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 3    Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 4    Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 5    Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# ..             ...            ...             ...            ...
# 455  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 456  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 457  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 458  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
# 459  Luguentz Dort  Aaron Wiggins  Jalen Williams  Cason Wallace
#
#                   PLAYER_1.5         PLAYER_2.1       PLAYER_2.2  \
# 0    Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 2    Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 3    Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 4    Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 5    Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# ..                       ...                ...              ...
# 455  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 456  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 457  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 458  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
# 459  Shai Gilgeous-Alexander  Julian Champagnie  Harrison Barnes
#
#        PLAYER_2.3      PLAYER_2.4  PLAYER_2.5  SCORE_1  SCORE_2 WINNER
# 0    Zach Collins  Stephon Castle  Chris Paul        0        0    SAS
# 2    Zach Collins  Stephon Castle  Chris Paul        0        2    SAS
# 3    Zach Collins  Stephon Castle  Chris Paul        3        2    SAS
# 4    Zach Collins  Stephon Castle  Chris Paul        3        5    SAS
# 5    Zach Collins  Stephon Castle  Chris Paul        3        5    SAS
# ..            ...             ...         ...      ...      ...    ...
# 455  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
# 456  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
# 457  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
# 458  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
# 459  Zach Collins  Stephon Castle  Chris Paul      104      110    SAS
#
# [459 rows x 19 columns]

# %%
train_set[10]
# Out:
#         GAME_ID  SCOREMARGIN  TIME_REMAINING  PERIOD TEAM_1 TEAM_2  \
# 33650  22400130            0               0       1    SAS    UTA
# 33651  22400130            0               0       1    SAS    UTA
# 33652  22400130           -2              19       1    SAS    UTA
# 33653  22400130           -2              33       1    SAS    UTA
# 33654  22400130           -2              35       1    SAS    UTA
# ...         ...          ...             ...     ...    ...    ...
# 34123  22400130           20            2857       4    SAS    UTA
# 34124  22400130           20            2867       4    SAS    UTA
# 34125  22400130           19            2867       4    SAS    UTA
# 34126  22400130           18            2867       4    SAS    UTA
# 34127  22400130           18            2880       4    SAS    UTA
#
#             PLAYER_1.1     PLAYER_1.2         PLAYER_1.3         PLAYER_1.4  \
# 33650  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# 33651  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# 33652  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# 33653  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# 33654  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# ...                ...            ...                ...                ...
# 34123  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# 34124  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# 34125  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# 34126  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
# 34127  Harrison Barnes  Jeremy Sochan  Victor Wembanyama  Julian Champagnie
#
#        PLAYER_1.5     PLAYER_2.1       PLAYER_2.2      PLAYER_2.3  \
# 33650  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# 33651  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# 33652  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# 33653  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# 33654  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# ...           ...            ...              ...             ...
# 34123  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# 34124  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# 34125  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# 34126  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
# 34127  Chris Paul  Cody Williams  Kyle Filipowski  Walker Kessler
#
#             PLAYER_2.4      PLAYER_2.5  SCORE_1  SCORE_2 WINNER
# 33650  Jordan Clarkson  Keyonte George        0        0    SAS
# 33651  Jordan Clarkson  Keyonte George        0        0    SAS
# 33652  Jordan Clarkson  Keyonte George        0        2    SAS
# 33653  Jordan Clarkson  Keyonte George        0        2    SAS
# 33654  Jordan Clarkson  Keyonte George        0        2    SAS
# ...                ...             ...      ...      ...    ...
# 34123  Jordan Clarkson  Keyonte George      106       86    SAS
# 34124  Jordan Clarkson  Keyonte George      106       86    SAS
# 34125  Jordan Clarkson  Keyonte George      106       87    SAS
# 34126  Jordan Clarkson  Keyonte George      106       88    SAS
# 34127  Jordan Clarkson  Keyonte George      106       88    SAS
#
# [478 rows x 19 columns]
